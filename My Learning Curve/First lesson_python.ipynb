# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# # First Lesson

# %% [markdown]
# # Variables in Python

# %%
x= 22

print(x)
# Out:
# 22

# %%
type(x)
# Out:
# int

# %%
y='Mint some'
print(y)
# Out:
# Mint some

# %%
type(y)
# Out:
# str

# %%
x,y,z = 12, 'chokolate', 'something'

print(x)
print(y)
print(z)
# Out:
# 12
# chokolate
# something

# %%
x=y=z='dick'

print(x)
print(y)
print(z)
# Out:
# dick
# dick
# dick

# %%
ice_cream = ['vanila', 'chokolate', 'mint']
x,y,z = ice_cream
print(x)
print(y)
print(z)
# Out:
# vanila
# chokolate
# mint

# %%
# Camel Case

#Test Variable Case

testVariableCase = 'Vanilla Swirl'

# %%
# Pascal Case

#Test Variable Case

TestVariableCase = 'Vanilla Swirl'

# %%
# Snake Case

#Test Variable Case

test_variable_case = 'Vanilla Swirl'

# %%
testvar = 'Vanila Swirl'
test_var = 'Vanila Swirl'
_test_var = 'Vanila Swirl'
TestVar = 'Vanila Swirl'
testvar2 = 'Vanila Swirl'

# %%
# Not to do
2testvar = 'Vanila Swirl'
test-Var2 = 'Vanila Swirl'
test Var = 'Vanila Swirl'

# %%
x = 'Ice craem' + '.'
print(x)
# Out:
# Ice craem.

# %%
y = 3 + 2
print(y)
# Out:
# 5

# %%
x = 'Ice craem' 
y = ' is'
z = '.'
print(x+y+z)
# Out:
# Ice craem is.

# %%
x = 'Ice craem' 
y = '2'
print(x,y)
# Out:
# Ice craem 2

# %% [markdown]
# # Data Types

# %%
type(-12+10)
# Out:
# int

# %%
type(-12+10.25)
# Out:
# float

# %%
type(-12+3j)
# Out:
# complex

# %%
# Boolean

type(True)
# Out:
# bool

# %%
1 > 5
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
# Strings

'Single quote'
# Out:
# 'Single quote'

# %%
"Double Quote"
# Out:
# 'Double Quote'

# %%
Multiple_Line = """
The Ice creame dfdfdfdffdfdfdfdfdfdfdfdf.
dfdfdf
dfdffd
"""

# %%
print(Multiple_Line)
# Out:
# The Ice creame dfdfdfdffdfdfdfdfdfdfdfdf.
# dfdfdf
# dfdffd

# %%
a = 'Hello world'

# %%
print(a[:5])
# Out:
# Hello

# %%
print(a[5])

# %%
print(a[-3])
# Out:
# r

# %%
print(a[2:5])
# Out:
# llo

# %%
a*3
# Out:
# 'Hello worldHello worldHello world'

# %%
a+a
# Out:
# 'Hello worldHello world'

# %%
# List

[1,2,3]
# Out:
# [1, 2, 3]

# %%
['Cookie', 'Strawberry', 2, ['Vanilla', 'Milk'], True]
# Out:
# ['Cookie', 'Strawberry', 2, ['Vanilla', 'Milk'], True]

# %%
Ice_cream = ['Cookie', 'Strawberry', 'Vanilla']
ice_cream.append('Salted Caramel')
ice_cream
# Out:
# ['vanila', 'chokolate', 'mint', 'Salted Caramel', 'Salted Caramel']

# %%
ice_cream[0] = 'Butter Pecam'
ice_cream
# Out:
# ['Butter Pecam', 'chokolate', 'mint', 'Salted Caramel', 'Salted Caramel']

# %%
nest_list = ['Cookie', 'Strawberry', 2, ['Vanilla', 'Milk'], True]

# %%
nest_list[3][1]
# Out:
# 'Milk'

# %%
# tuple

tuple_scoops = (1,2,3,2,1)

# %%
type(tuple_scoops)
# Out:
# tuple

# %%
tuple_scoops[0]
# Out:
# 1

# %%
tuple_scoops.append(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 tuple_scoops.append(3)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# sets

daily_pints = {1,2,3}

# %%
type(daily_pints)
# Out:
# set

# %%
daily_pints_log = {1,2,3,1,2,3,1,2,3,5}

# %%
print(daily_pints_log )
# Out:
# {1, 2, 3, 5}

# %%
wife_daily_pints_log = {1,2,3,4,4,4,4,4}

# %%
print(daily_pints_log | wife_daily_pints_log)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(daily_pints_log & wife_daily_pints_log)
# Out:
# {1, 2, 3}

# %%
print(wife_daily_pints_log - daily_pints_log)
# Out:
# {4}

# %%
print(wife_daily_pints_log ^ daily_pints_log)
# Out:
# {4, 5}

# %%
# dictionaries
# Key/Value Pair
dict_cream = {'name': 'Alex Freberg', 'weekly intake': 5, 'favorite ice creams':['MCC','bannana']}

# %%
type(dict_cream)
# Out:
# dict

# %%
print(dict_cream)
# Out:
# {'name': 'Alex Freberg', 'weekly intake': 5, 'favorite ice creams': ['MCC', 'bannana']}

# %%
dict_cream.values()
# Out:
# dict_values(['Alex Freberg', 5, ['MCC', 'bannana']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'favorite ice creams'])

# %%
dict_cream.items()
# Out:
# dict_items([('name', 'Alex Freberg'), ('weekly intake', 5), ('favorite ice creams', ['MCC', 'bannana'])])

# %%
dict_cream['name']
# Out:
# 'Alex Freberg'

# %%
dict_cream['name'] = 'Mykola Herasymchuk'
print(dict_cream)
# Out:
# {'name': 'Mykola Herasymchuk', 'weekly intake': 5, 'favorite ice creams': ['MCC', 'bannana']}

# %%
dict_cream.update({'name': 'Mykola Herasymchuk', 'weekly intake': 10, 'mass': 300})
print(dict_cream)
# Out:
# {'name': 'Mykola Herasymchuk', 'weekly intake': 10, 'favorite ice creams': ['MCC', 'bannana'], 'mass': 300}

# %%
del dict_cream['mass']
print(dict_cream)
# Out:
# {'name': 'Mykola Herasymchuk', 'weekly intake': 10, 'favorite ice creams': ['MCC', 'bannana']}

# %% [markdown]
# ![image.png](attachment:cb3faa7e-8929-4bbd-8a09-9da3f85a6452.png)

# %%
10 == 10
# Out:
# True

# %%
12 !=10
# Out:
# True

# %%
10 <=10
# Out:
# True

# %% [markdown]
# # Logical Operators

# %%
(10 > 50) and (10 < 50)
# Out:
# False

# %%
(10 > 50) or (10 < 50)
# Out:
# True

# %%
not (10 < 50)
# Out:
# False

# %%
'V' > 'C'
# Out:
# True

# %% [markdown]
# # Membership Operators

# %%
ice = "I`m Love Chokolate ice cream"
'Love' in ice
# Out:
# True

# %%
scoops = [1,2,3,4,5]
2 in scoops
# Out:
# True

# %%
6 not in scoops
# Out:
# True

# %% [markdown]
# # if - Elif -Else Statements

# %% [markdown]
# ![image.png](attachment:ae9b0660-b5c8-44a1-971b-52bd878e667f.png)

# %%
if 25 > 10:
    print('it worked')
# Out:
# it worked

# %%
if 25 < 10:
    print('it worked')
else:
    print('it did not work')
# Out:
# it did not work

# %%
if 25 < 10:
    print('it worked')
elif 25 < 30:
    print('elif worked')
else:
    print('it did not work')
# Out:
# elif worked

# %%
if (25 < 10) or (1 < 3):
    print('it worked')
else:
    print('it did not work')
# Out:
# it worked

# %%
print('it worked') if 10>30 else print('it did`t work')
# Out:
# it did`t work

# %%
if (25 < 10) or (1 < 3):
    print('it worked')
    if 10 > 5:
        print("This nested 'if statement' worked")
elif 25 < 20:
    print('elif 2 worked')
elif 25 < 30:
    print('elif 3 worked')
else:
    print('it did not work')
# Out:
# it worked
# This nested 'if statement' worked

# %% [markdown]
# # For Loops

# %% [markdown]
# ![image.png](attachment:6c3baa34-fed0-4a7c-9e0c-b5c555542a63.png)

# %%
integers = [1,2,3,4,5]

# %%
for number in integers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for number in integers:
    print('yeah')
# Out:
# yeah
# yeah
# yeah
# yeah
# yeah

# %%
for bleh in integers:
    print(bleh + bleh)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
ice_cream_dict = {'name': 'Alex Freberg', 'weekly intake': 5, 'favorite ice creams':['MCC','bannana']}

# %%
for cream in ice_cream_dict.values():
    print(cream)
# Out:
# Alex Freberg
# 5
# ['MCC', 'bannana']

# %%
for key, values in ice_cream_dict.items():
    print(key, '->', values)
# Out:
# name -> Alex Freberg
# weekly intake -> 5
# favorite ice creams -> ['MCC', 'bannana']

# %% [markdown]
# # Nested For Loops

# %%
flavors = ['Vanilla', 'Chocolate', 'Cookie Dough']
toppings = ['Hot chokolate', 'Oreos', 'sparkles']

# %%
for one in flavors:
    for two in toppings:
        print(one, 'topped with', two)
# Out:
# Vanilla topped with Hot chokolate
# Vanilla topped with Oreos
# Vanilla topped with sparkles
# Chocolate topped with Hot chokolate
# Chocolate topped with Oreos
# Chocolate topped with sparkles
# Cookie Dough topped with Hot chokolate
# Cookie Dough topped with Oreos
# Cookie Dough topped with sparkles

# %% [markdown]
# # While Loops

# %% [markdown]
# ![image.png](attachment:df5c0ead-c551-4546-b3ea-50de95294465.png)

# %%
number = 0
while number <= 5:
    print(number)
    number = number + 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
number = 0
while number <= 5:
    print(number)
    if number == 3:
        break
    number = number + 1
# Out:
# 0
# 1
# 2
# 3

# %%
number = 0
while number < 5:
    print(number)
    if number == 6:
        break
    number = number + 1
else:
    print('No Longer < 5')
# Out:
# 0
# 1
# 2
# 3
# 4
# No Longer < 5

# %%
number = 0
while number <= 5:
    number = number + 1
    if number == 3:
        continue
    print(number)
else:
    print('No Longer < 5')
# Out:
# 1
# 2
# 4
# 5
# 6
# No Longer < 5

# %% [markdown]
# # Functions

# %%
def function():
    print('My first function')   # Function and Body
function()   # Function Call
# Out:
# My first function

# %%
def number_squared(number):
    print(number**2)

# %%
number_squared(5)
# Out:
# 25

# %%
def number_squared_cust(number, power):
    print(number**power)

# %%
number_squared_cust(5,3)
# Out:
# 125

# %%
args_tuple = (5,6,7,8)

def number_args(*args):
    print(args[0]*args[1])

# %%
number_args(*args_tuple)
# Out:
# 30

# %%
def number_squared_cust(number, power):
    print(number**power)

# %%
number_squared_cust(power = 5,number = 3)
# Out:
# 243

# %%
def number_kwarg(**number):
    print('My number is: ' + number['integer'] + ' My other number: ' + number['integer2'])

# %%
number_kwarg(integer = '2309', integer2 = '349')
# Out:
# My number is: 2309 My other number: 349

# %% [markdown]
# # Converting Data Types

# %%
num_int = 7
type(num_int)
# Out:
# int

# %%
num_str = '7'
type(num_str)
# Out:
# str

# %%
num_str_conv = int(num_str)
type(num_str_conv)
# Out:
# int

# %%
num_sum = num_int + num_str_conv
print(num_sum)
# Out:
# 14

# %%
list_type = [1,2,3]
type(list_type)
# Out:
# list

# %%
type(tuple(list_type))
# Out:
# tuple

# %%
list_type = [1,2,3,3,3,3, 2,1,2]

# %%
set(list_type)
# Out:
# {1, 2, 3}

# %%
dict_type = {'name': 'Alex', 'age': 28, 'hair': 'blonde'}
type(dict_type)
# Out:
# dict

# %%
dict_type.items()
# Out:
# dict_items([('name', 'Alex'), ('age', 28), ('hair', 'blonde')])

# %%
dict_type.values()
# Out:
# dict_values(['Alex', 28, 'blonde'])

# %%
dict_type.keys()
# Out:
# dict_keys(['name', 'age', 'hair'])

# %%
list(dict_type.keys())
# Out:
# ['name', 'age', 'hair']

# %%
type(list(dict_type.keys()))
# Out:
# list

# %%
type(list(dict_type.values()))
# Out:
# list

# %%
long_str = "I like to eat ice cream"

set(long_str)
# Out:
# {' ', 'I', 'a', 'c', 'e', 'i', 'k', 'l', 'm', 'o', 'r', 't'}
