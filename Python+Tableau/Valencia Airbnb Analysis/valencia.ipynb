# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\Data_Analytics\Tableau\Portfolio\listings.csv")
pd.set_option('display.max.columns', 200)
df
# Out:
#                        id                                       listing_url  \
# 0                   48154                https://www.airbnb.com/rooms/48154
# 1                  137143               https://www.airbnb.com/rooms/137143
# 2                  149715               https://www.airbnb.com/rooms/149715
# 3                  165971               https://www.airbnb.com/rooms/165971
# 4                  182221               https://www.airbnb.com/rooms/182221
# ...                   ...                                               ...
# 7846  1715265355544470004  https://www.airbnb.com/rooms/1715265355544470004
# 7847  1715277710199680475  https://www.airbnb.com/rooms/1715277710199680475
# 7848  1715338905046170969  https://www.airbnb.com/rooms/1715338905046170969
# 7849  1716011270454334701  https://www.airbnb.com/rooms/1716011270454334701
# 7850  1716042440767325687  https://www.airbnb.com/rooms/1716042440767325687
#
#            scrape_id last_scraped           source  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7851 entries, 0 to 7850
# Data columns (total 90 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7851 non-null   int64
#  1   listing_url                                   7851 non-null   str
#  2   scrape_id                                     7851 non-null   int64
#  3   last_scraped                                  7851 non-null   str
#  4   source                                        7851 non-null   str
#  5   name                                          7851 non-null   str
#  6   description                                   7678 non-null   str
#  7   neighborhood_overview                         0 non-null      float64
#  8   picture_url                                   7851 non-null   str
#  9   host_id                                       7851 non-null   int64
# ...

# %%
df = df.drop_duplicates()

# %%
df = df.drop(columns = ['instant_bookable', 'calendar_updated', 'neighbourhood', 'host_verifications', 'host_total_listings_count', 'host_neighbourhood', 'host_thumbnail_url', 'host_acceptance_rate', 'host_response_rate', 'host_response_time', 'host_since', 'neighborhood_overview'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7851 entries, 0 to 7850
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7851 non-null   int64
#  1   listing_url                                   7851 non-null   str
#  2   scrape_id                                     7851 non-null   int64
#  3   last_scraped                                  7851 non-null   str
#  4   source                                        7851 non-null   str
#  5   name                                          7851 non-null   str
#  6   description                                   7678 non-null   str
#  7   picture_url                                   7851 non-null   str
#  8   host_id                                       7851 non-null   int64
#  9   host_url                                      7851 non-null   str
# ...

# %%
df
# Out:
#                        id                                       listing_url  \
# 0                   48154                https://www.airbnb.com/rooms/48154
# 1                  137143               https://www.airbnb.com/rooms/137143
# 2                  149715               https://www.airbnb.com/rooms/149715
# 3                  165971               https://www.airbnb.com/rooms/165971
# 4                  182221               https://www.airbnb.com/rooms/182221
# ...                   ...                                               ...
# 7846  1715265355544470004  https://www.airbnb.com/rooms/1715265355544470004
# 7847  1715277710199680475  https://www.airbnb.com/rooms/1715277710199680475
# 7848  1715338905046170969  https://www.airbnb.com/rooms/1715338905046170969
# 7849  1716011270454334701  https://www.airbnb.com/rooms/1716011270454334701
# 7850  1716042440767325687  https://www.airbnb.com/rooms/1716042440767325687
#
#            scrape_id last_scraped           source  \
# ...

# %%
df.isnull().sum()
# Out:
# id                                                0
# listing_url                                       0
# scrape_id                                         0
# last_scraped                                      0
# source                                            0
#                                                ...
# calculated_host_listings_count                    0
# calculated_host_listings_count_entire_homes       0
# calculated_host_listings_count_private_rooms      0
# calculated_host_listings_count_shared_rooms       0
# reviews_per_month                               930
# Length: 78, dtype: int64

# %%
df.nunique()
# Out:
# id                                              7851
# listing_url                                     7851
# scrape_id                                          1
# last_scraped                                       3
# source                                             2
#                                                 ...
# calculated_host_listings_count                    47
# calculated_host_listings_count_entire_homes       44
# calculated_host_listings_count_private_rooms      19
# calculated_host_listings_count_shared_rooms        5
# reviews_per_month                                664
# Length: 78, dtype: int64

# %%
df["name"] = df["name"].str.strip("123._/★")
df["host_name"] = df["host_name"].str.strip("123._/")
df
# Out:
#                        id                                       listing_url  \
# 0                   48154                https://www.airbnb.com/rooms/48154
# 1                  137143               https://www.airbnb.com/rooms/137143
# 2                  149715               https://www.airbnb.com/rooms/149715
# 3                  165971               https://www.airbnb.com/rooms/165971
# 4                  182221               https://www.airbnb.com/rooms/182221
# ...                   ...                                               ...
# 7846  1715265355544470004  https://www.airbnb.com/rooms/1715265355544470004
# 7847  1715277710199680475  https://www.airbnb.com/rooms/1715277710199680475
# 7848  1715338905046170969  https://www.airbnb.com/rooms/1715338905046170969
# 7849  1716011270454334701  https://www.airbnb.com/rooms/1716011270454334701
# 7850  1716042440767325687  https://www.airbnb.com/rooms/1716042440767325687
#
#            scrape_id last_scraped           source  \
# ...

# %%
df=df.fillna('')
df
# Out:
#                        id                                       listing_url  \
# 0                   48154                https://www.airbnb.com/rooms/48154
# 1                  137143               https://www.airbnb.com/rooms/137143
# 2                  149715               https://www.airbnb.com/rooms/149715
# 3                  165971               https://www.airbnb.com/rooms/165971
# 4                  182221               https://www.airbnb.com/rooms/182221
# ...                   ...                                               ...
# 7846  1715265355544470004  https://www.airbnb.com/rooms/1715265355544470004
# 7847  1715277710199680475  https://www.airbnb.com/rooms/1715277710199680475
# 7848  1715338905046170969  https://www.airbnb.com/rooms/1715338905046170969
# 7849  1716011270454334701  https://www.airbnb.com/rooms/1716011270454334701
# 7850  1716042440767325687  https://www.airbnb.com/rooms/1716042440767325687
#
#            scrape_id last_scraped           source  \
# ...

# %%
#for x in df.index:
#    if df.loc[x, "host_location"] != 'Valencia, Spain':
#        df.loc(x, 'host_location') = 'Valencia, Spain'
df.loc[df["host_location"] != "Valencia, Spain", "host_location"] = ("Valencia, Spain")
df
# Out:
#                        id                                       listing_url  \
# 0                   48154                https://www.airbnb.com/rooms/48154
# 1                  137143               https://www.airbnb.com/rooms/137143
# 2                  149715               https://www.airbnb.com/rooms/149715
# 3                  165971               https://www.airbnb.com/rooms/165971
# 4                  182221               https://www.airbnb.com/rooms/182221
# ...                   ...                                               ...
# 7846  1715265355544470004  https://www.airbnb.com/rooms/1715265355544470004
# 7847  1715277710199680475  https://www.airbnb.com/rooms/1715277710199680475
# 7848  1715338905046170969  https://www.airbnb.com/rooms/1715338905046170969
# 7849  1716011270454334701  https://www.airbnb.com/rooms/1716011270454334701
# 7850  1716042440767325687  https://www.airbnb.com/rooms/1716042440767325687
#
#            scrape_id last_scraped           source  \
# ...

# %%
#df2 = pd.read_csv(r"D:\Data_Analytics\Tableau\Portfolio\calendar.csv")
#df.merge(df2, how = 'inner', on = ['id', 'listing_id'])

# %%
#df.to_excel(r"D:\Data_Analytics\Python\Portfolio\listings.xlsx", index = False)

# %%
price = pd.to_numeric(df["price_quote_price_per_night"], errors="coerce")
price
# Out:
# 0       145.50
# 1          NaN
# 2       485.00
# 3       211.20
# 4       352.20
#          ...
# 7846     85.12
# 7847     99.00
# 7848    227.50
# 7849     45.65
# 7850       NaN
# Name: price_quote_price_per_night, Length: 7851, dtype: float64

# %%
price.dropna.plot(kind="hist")

# %%
type(df['price_quote_price_per_night'])
#df.plot.bar(x = 'neighbourhood_cleansed', y = 'price_quote_price_per_night')
# Out:
# pandas.Series
